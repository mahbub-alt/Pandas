# %%
import pandas as pd
import numpy as np

# %%
# def data_analysis(df1,  df2):
#     print(df1.shape, df2.shape)
#     train_dtype = []
#     train_isnull = []
#     train_unique = []
#     test_dtype = []
#     test_isnull = []
#     test_unique = []
#     col_categories = []
#     col_replace1 = []
#     col_replace2 = []
#     for col in df2.columns:
#         train_dtype.append(df1[col].dtypes)
#         train_isnull.append(df1[col].isnull().sum())
#         train_unique.append(df1[col].unique().shape[0])
#         test_dtype.append(df2[col].dtypes)
#         test_isnull.append(df2[col].isnull().sum())
#         test_unique.append(df2[col].unique().shape[0])

#         if df1[col].dtypes == 'object':
#           col_categories.append(col)
#         if df1[col].isnull().sum() > 0:
#           col_replace1.append(col)
#         if df2[col].isnull().sum() > 0:
#           col_replace2.append(col)

#     print('col_categories:', col_categories)
#     print('col_replace1:', col_replace1)
#     print('col_replace2:', col_replace2)
#     df = pd.DataFrame({'train_dtype':train_dtype,'test_dtype':test_dtype,'train_isnull':train_isnull,'test_isnull':test_isnull,
#                        'train_unique':train_unique,'test_unique':test_unique}, index=df2.columns)
#     df.sort_values(['train_isnull'], axis=0, ascending=False, inplace=True)
#     return df

# %%
# def group_numeric(pdf):
# #     for col in pdf.columns:                     #either u need to write these two lines of below one
# #         if pdf[col].dtypes =="float64":
#         list(pdf.select_dtypes([np.int64,np.float64]).columns)
#             display(pdf[list(pdf)].describe())
    
# group_numeric(Aquifer_Auser)

# %%
print(test_csv.isnull().sum().sort_values(ascending=False).loc[lambda x : x!=0]) # really fantastic code

# %%
df=pd.read_excel('water quality.xlsx')
df
# Out:
#     LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              Aliabad        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %%
def dup (arr):
    for i in range(0, len(arr)): 
        print(i)
        for j in range(i+1, len(arr)):
            print('fff', j)
            if(arr[i] == arr[j]):    
#                 print(arr[j]); 
                return arr[j]
                
                
dup (df.UNION)
# Out:
# 0
# fff 1
# 'Faridpur Paurashava'

# %%
def fun (x):
    if x== '15':
        return 'house'
    elif x== '44':
        return 'mosque/ Temple'
    else:
        return x

# %%
def dup (arr):
    for i in range(0, len(arr)): 
        for j in range(i+1, len(arr)):
            if arr[i] == arr[j]:     
                print (arr[j])
            else:
                print('no dupli')
                
                
dup ([4,2,4,5,5,6,7,8])
# Out:
# no dupli
# 4
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# 5
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli
# no dupli

# %%
                
def dup (arr):
    for i in range(0, len(arr)): 
        for j in range(i+1, len(arr)):
            if arr[i] == arr[j]:
                print (arr[j])
        else:
            print('')
                
                
dup ([4,2,4,5,5,6,7,8])
# Out:
# 4
#
#
#
# 5

# %%
def fun (x):
    
    if x == 'Dhaka' or x == 'Faridpur':
        return 5
    else:
        return 0.0

# %%
a = np.array([[5,7],[2,1]])
b= np.add(a,2)
c = b**2
c
# Out:
# array([[49, 81],
#        [16,  9]], dtype=int32)

# %%
49+81+16+9
# Out:
# 155

# %% [markdown]
# # data structure

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['UNION']
# Out:
# 0     Faridpur Paurashava
# 1     Faridpur Paurashava
# 2               Ambikapur
# 3     Faridpur Paurashava
# 4                 Aliabad
#              ...
# 59                Kaijuri
# 60                Majchar
# 61    Faridpur Paurashava
# 62    Faridpur Paurashava
# 63                Aliabad
# Name: UNION, Length: 64, dtype: object

# %% [markdown]
# # indexing

# %%
df[['Ca','Mn']]
# Out:
#        Ca     Mn
# 0   127.0  1.470
# 1   142.0  1.130
# 2   116.0  1.130
# 3   116.0  0.999
# 4    88.4  0.080
# ..    ...    ...
# 59   67.9  0.246
# 60  103.0  0.822
# 61   76.4  0.078
# 62  106.0  0.581
# 63   54.6  0.136
#
# [64 rows x 2 columns]

# %%
df.Ca
# Out:
# 0     127.0
# 1     142.0
# 2     116.0
# 3     116.0
# 4      88.4
#       ...
# 59     67.9
# 60    103.0
# 61     76.4
# 62    106.0
# 63     54.6
# Name: Ca, Length: 64, dtype: float64

# %%
df
# Out:
#     LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              Aliabad        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %%
df.iloc[:,4]
# Out:
# 0     471
# 1     580
# 2     529
# 3     568
# 4     561
#      ...
# 59    485
# 60    485
# 61    536
# 62    668
# 63    432
# Name: HCO3, Length: 64, dtype: int64

# %%
df.iloc[2,:]
# Out:
# LAT_DEG       23.6031
# LONG_DEG      89.8272
# Location    Ambikapur
# x                36.6
# HCO3              529
# Ca                116
# Cl               33.9
# F                 0.2
# Fe                9.6
# K                 3.9
# Mg               32.5
# Na                 19
# NO3               0.2
# pH               6.99
# SO4               8.2
# Mn               1.13
# AsIII              27
# Name: 2, dtype: object

# %%
df.loc[2:10,['HCO3','Mg']]
# Out:
#     HCO3    Mg
# 2    529  32.5
# 3    568  30.6
# 4    561  40.0
# 5    563  40.0
# 6    590  38.6
# 7    848  40.6
# 8    563  29.9
# 9    607  28.0
# 10   502  23.2

# %%
df.loc[df['Ca']>88]
# Out:
#     LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca     Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0   27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0    9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0   33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0   16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4   13.5
# 6   23.5622   89.7992              Kaijuri        65.5   590  104.0    3.4
# 7   23.5553   89.8125              Kaijuri        53.3   848   98.9  127.0
# 8   23.5092   89.8197              Kaijuri        49.7   563  115.0   16.2
# 9   23.5094   89.8103             Kanaipur        25.9   607  123.0    3.6
# 10  23.5331   89.7900             Kanaipur        26.2   502  115.0    1.8
# 15  23.5747   89.8825              Aliabad        40.5   566   95.7    7.6
# ...

# %%
# df.loc[df.UNION=='Aliabad']
df[df.UNION.str.contains('^A')]
# Out:
#     LAT_DEG  LONG_DEG      UNION  WELL_DEPTH  HCO3     Ca    Cl     F      Fe  \
# 2   23.6031   89.8272  Ambikapur        36.6   529  116.0  33.9  0.20   9.600
# 4   23.5689   89.8536    Aliabad        45.7   561   88.4  13.5  0.24   7.680
# 15  23.5747   89.8825    Aliabad        40.5   566   95.7   7.6  0.11   8.830
# 16  23.5586   89.9025    Aliabad        41.1   714  167.0   5.5  0.14   1.100
# 17  23.5969   89.8769    Aliabad        20.1   553  129.0   3.8  0.10   2.210
# 21  23.6292   89.8278  Ambikapur        32.0   402  101.0  16.0  0.06   0.827
# 37  23.5972   89.7900  Ambikapur        20.1   380   89.2   8.7  0.09   0.483
# 44  23.5783   89.8942    Aliabad        48.8   773  138.0  17.7  0.08  10.100
# 56  23.5842   89.8611    Aliabad        49.7   249   34.8   4.0  0.16   3.370
# 63  23.5919   89.8417    Aliabad        50.0   432   54.6   4.8  0.16   6.270
#
#       K    Mg    Na  NO3    pH   SO4     Mn  AsIII
# 2   3.9  32.5  19.0  0.2  6.99   8.2  1.130     27
# ...

# %%
df.loc[(df['Ca']>88) & (df['Ca']<=120)]
# Out:
#     LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca     Cl  \
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0   33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0   16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4   13.5
# 6   23.5622   89.7992              Kaijuri        65.5   590  104.0    3.4
# 7   23.5553   89.8125              Kaijuri        53.3   848   98.9  127.0
# 8   23.5092   89.8197              Kaijuri        49.7   563  115.0   16.2
# 10  23.5331   89.7900             Kanaipur        26.2   502  115.0    1.8
# 15  23.5747   89.8825              Aliabad        40.5   566   95.7    7.6
# 21  23.6292   89.8278            Ambikapur        32.0   402  101.0   16.0
# 22  23.6700   89.7253       Ishan Gopalpur        29.0   534   94.5    1.8
# 24  23.6436   89.7828       Ishan Gopalpur        38.7   497   97.4   11.5
# ...

# %%
df.shape[0]
# Out:
# 64

# %%
len(df)
# Out:
# 64

# %%
df.describe().T
# Out:
#             count        mean         std       min         25%        50%  \
# LAT_DEG      64.0   23.591833    0.046104   23.4958   23.563475   23.58625
# LONG_DEG     64.0   89.815016    0.048968   89.6975   89.785750   89.81625
# WELL_DEPTH   64.0   46.229688   43.011585   13.7000   24.400000   32.00000
# HCO3         64.0  541.812500  127.345658  200.0000  476.250000  554.50000
# Ca           64.0  103.725000   35.518160   34.8000   78.275000  101.00000
# Cl           64.0   24.675000   36.600963    1.8000    4.650000   10.45000
# F            64.0    0.121875    0.060968    0.0200    0.087500    0.12000
# Fe           64.0    5.642125    4.923974    0.0520    0.866000    5.55000
# K            64.0    4.965625    1.364891    2.6000    3.975000    4.75000
# Mg           64.0   32.680000   10.096984    8.9200   25.900000   32.10000
# Na           64.0   36.435937   39.570714    5.1000   13.800000   21.10000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LAT_DEG     64 non-null     float64
#  1   LONG_DEG    64 non-null     float64
#  2   UNION       64 non-null     object
#  3   WELL_DEPTH  64 non-null     float64
#  4   HCO3        64 non-null     int64
#  5   Ca          64 non-null     float64
#  6   Cl          64 non-null     float64
#  7   F           64 non-null     float64
#  8   Fe          64 non-null     float64
#  9   K           64 non-null     float64
#  10  Mg          64 non-null     float64
#  11  Na          64 non-null     float64
#  12  NO3         64 non-null     float64
#  13  pH          64 non-null     float64
#  14  SO4         64 non-null     float64
#  15  Mn          64 non-null     float64
#  16  AsIII       64 non-null     int64
# dtypes: float64(14), int64(2), object(1)
# memory usage: 8.6+ KB

# %%
df.Ca.dtype
# Out:
# dtype('float64')

# %%
df.UNION.unique().shape[0]
# Out:
# 12

# %%
df.Ca.unique().shape[0]
# Out:
# 57

# %%
df.head()
# Out:
#    LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca    Cl  \
# 0  23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1  23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2  23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3  23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4  23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
#
#       F     Fe    K    Mg    Na  NO3    pH   SO4     Mn  AsIII
# 0  0.20  0.447  4.5  27.8  22.5  0.2  6.84  13.5  1.470      7
# 1  0.40  4.240  3.9  29.6  25.0  0.2  7.17   0.2  1.130    990
# 2  0.20  9.600  3.9  32.5  19.0  0.2  6.99   8.2  1.130     27
# 3  0.10  0.944  6.2  30.6  30.9  0.2  6.82   3.9  0.999      4
# 4  0.24  7.680  5.0  40.0  36.6  4.7  6.82   0.5  0.080      4

# %%
df.rename(columns = {'UNION':'Location',"WELL_DEPTH":"x"},inplace = True)

# %%
df
# Out:
#     LAT_DEG  LONG_DEG             Location  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              Aliabad        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %% [markdown]
# # math

# %%
df.min()
# Out:
# LAT_DEG       23.4958
# LONG_DEG      89.6975
# Location      Aliabad
# WELL_DEPTH       13.7
# HCO3              200
# Ca               34.8
# Cl                1.8
# F                0.02
# Fe              0.052
# K                 2.6
# Mg               8.92
# Na                5.1
# NO3               0.2
# pH               6.38
# SO4               0.1
# Mn              0.041
# AsIII               4
# dtype: object

# %%
df.mean()
# Out:
# LAT_DEG        23.591833
# LONG_DEG       89.815016
# WELL_DEPTH     46.229688
# HCO3          541.812500
# Ca            103.725000
# Cl             24.675000
# F               0.121875
# Fe              5.642125
# K               4.965625
# Mg             32.680000
# Na             36.435937
# NO3             0.453125
# pH              6.905781
# SO4             4.307813
# Mn              0.656109
# AsIII          47.484375
# dtype: float64

# %%
df.Mn.agg(['mean','std'])
# Out:
# mean    0.656109
# std     0.721039
# Name: Mn, dtype: float64

# %%
df.skew()
# Out:
# LAT_DEG       0.201791
# LONG_DEG     -0.453848
# WELL_DEPTH    2.748803
# HCO3         -0.104736
# Ca            0.378794
# Cl            2.581103
# F             1.489871
# Fe            0.912829
# K             0.738517
# Mg            0.174392
# Na            2.048597
# NO3           3.949536
# pH           -0.334684
# SO4           3.962840
# Mn            2.525428
# AsIII         6.561250
# dtype: float64

# %%
df.kurtosis()
# Out:
# LAT_DEG       -0.335218
# LONG_DEG      -0.335813
# WELL_DEPTH     7.320329
# HCO3           0.655510
# Ca            -0.057717
# Cl             7.523142
# F              5.685014
# Fe             0.626452
# K              0.120133
# Mg            -0.043214
# Na             3.381271
# NO3           14.899421
# pH             0.381011
# SO4           17.418376
# Mn             9.361532
# AsIII         48.035311
# dtype: float64

# %% [markdown]
# # Groupby method

# %%
df.head(2)
# Out:
#    LAT_DEG  LONG_DEG             Location  WELL_DEPTH  HCO3     Ca    Cl    F  \
# 0  23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6  0.2
# 1  23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3  0.4
#
#       Fe    K    Mg    Na  NO3    pH   SO4    Mn  AsIII
# 0  0.447  4.5  27.8  22.5  0.2  6.84  13.5  1.47      7
# 1  4.240  3.9  29.6  25.0  0.2  7.17   0.2  1.13    990

# %%
df.drop(['LAT_DEG','LONG_DEG'],axis =1,inplace = True)

# %%
df.head()
# Out:
#               Location  WELL_DEPTH  HCO3     Ca    Cl     F     Fe    K    Mg  \
# 0  Faridpur Paurashava        24.4   471  127.0  27.6  0.20  0.447  4.5  27.8
# 1  Faridpur Paurashava        27.4   580  142.0   9.3  0.40  4.240  3.9  29.6
# 2            Ambikapur        36.6   529  116.0  33.9  0.20  9.600  3.9  32.5
# 3  Faridpur Paurashava        18.9   568  116.0  16.5  0.10  0.944  6.2  30.6
# 4              Aliabad        45.7   561   88.4  13.5  0.24  7.680  5.0  40.0
#
#      Na  NO3    pH   SO4     Mn  AsIII
# 0  22.5  0.2  6.84  13.5  1.470      7
# 1  25.0  0.2  7.17   0.2  1.130    990
# 2  19.0  0.2  6.99   8.2  1.130     27
# 3  30.9  0.2  6.82   3.9  0.999      4
# 4  36.6  4.7  6.82   0.5  0.080      4

# %%
# %matplotlib notebook
df.groupby('Location').mean().plot(kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-897d38f05b23> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
# ----> 2 df.groupby('Location').mean().plot(kind = 'bar')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5799         axis = self._get_axis_number(axis)
#    5800
# -> 5801         return groupby_generic.DataFrameGroupBy(
#    5802             obj=self,
#    5803             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     401             from pandas.core.groupby.grouper import get_grouper
#     402
# --> 403             grouper, exclusions, obj = get_grouper(
# ...

# %%
df.groupby('Location')['Ca'].agg(['mean','std']).plot(kind ='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
plt.figure()
df.groupby('Location')['Ca'].count().plot(kind = 'bar')
# Out:
# <img src="data:image/png;base64,..." width="627.84">

# %%
df['percentage_ca'] = df.Ca/sum(df.Ca)* 100

# %%
df
# Out:
#     LAT_DEG  LONG_DEG             Location  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              Aliabad        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII  \
# ...

# %% [markdown]
# # replace

# %%
df.AsIII.replace([4,990,7],[50,100,0])
# Out:
# 0       0
# 1     100
# 2      27
# 3      50
# 4      50
#      ...
# 59     16
# 60     50
# 61     74
# 62     50
# 63     90
# Name: AsIII, Length: 64, dtype: int64

# %% [markdown]
# # apply

# %% [markdown]
# # Tidy data

# %%
df = pd.read_csv('country_timeseries.csv')
df
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %% [markdown]
# # Duplicates

# %%
#duplicates are actually those rows  that occur repeatedly in your dataset

# %%
df = pd.read_excel("water quality.xlsx")
df
# Out:
#     LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              Aliabad        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df2=df.loc[0:15,:]

# %%
nwdf= pd.concat((df,df2))

# %%
nwdf
# Out:
#     LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 11  23.4958   89.7861             Kanaipur        40.5   536   87.4  10.4
# 12  23.5158   89.8397              Kaijuri        53.3   614   57.1  56.7
# 13  23.5311   89.8531                Greda        50.3   502   43.9  86.0
# 14  23.5347   89.8675                Greda        32.0   410   49.2   2.0
# 15  23.5747   89.8825              Aliabad        40.5   566   95.7   7.6
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %%
nwdf.loc[nwdf.duplicated()]
# Out:
#     LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca     Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0   27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0    9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0   33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0   16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4   13.5
# 5   23.5792   89.8014              Kaijuri        54.3   563   65.7    7.2
# 6   23.5622   89.7992              Kaijuri        65.5   590  104.0    3.4
# 7   23.5553   89.8125              Kaijuri        53.3   848   98.9  127.0
# 8   23.5092   89.8197              Kaijuri        49.7   563  115.0   16.2
# 9   23.5094   89.8103             Kanaipur        25.9   607  123.0    3.6
# 10  23.5331   89.7900             Kanaipur        26.2   502  115.0    1.8
# ...

# %%
nwdf.drop_duplicates(inplace =True)
nwdf
# Out:
#     LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              Aliabad        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %% [markdown]
# # Join

# %%
df = pd.read_csv('rainYearly.csv')
df
# Out:
#     Year  Rainfall
# 0   1956      1.01
# 1   1957      1.66
# 2   1958      3.50
# 3   1959      3.31
# 4   1960      3.61
# ..   ...       ...
# 56  2013      1.50
# 57  2014      1.76
# 58  2015      6.73
# 59  2016      3.21
# 60  2017      2.00
#
# [61 rows x 2 columns]

# %%
df2 = pd.read_csv('tempYearly.csv')
df2
# Out:
#     Year  Temperature
# 0   1956        16.99
# 1   1957        10.34
# 2   1958        21.01
# 3   1959        23.68
# 4   1960        24.59
# ..   ...          ...
# 57  2013        26.41
# 58  2014        11.24
# 59  2015        48.27
# 60  2016        20.29
# 61  2017        13.81
#
# [62 rows x 2 columns]

# %%
ndf=pd.merge(df,df2, on ='Year', how = 'inner')

# %%
ndf
# Out:
#     Year  Rainfall  Temperature
# 0   1956      1.01        16.99
# 1   1957      1.66        10.34
# 2   1958      3.50        21.01
# 3   1959      3.31        23.68
# 4   1960      3.61        24.59
# ..   ...       ...          ...
# 56  2013      1.50        26.41
# 57  2014      1.76        11.24
# 58  2015      6.73        48.27
# 59  2016      3.21        20.29
# 60  2017      2.00        13.81
#
# [61 rows x 3 columns]

# %%
ndf.isnull().sum()
# Out:
# Year           0
# Rainfall       0
# Temperature    0
# dtype: int64

# %% [markdown]
# # Tidy data

# %%
df = pd.read_csv('pew.csv')
df
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
df.melt(id_vars='religion',var_name ='income_range',value_name='count' )
# Out:
#                   religion        income_range  count
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
ebola = pd.read_csv('country_timeseries.csv')
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
df= ebola.melt(id_vars =['Date','Day'], var_name ='Country', value_name='count')
df
# Out:
#             Date  Day       Country   count
# 0       1/5/2015  289  Cases_Guinea  2776.0
# 1       1/4/2015  288  Cases_Guinea  2775.0
# 2       1/3/2015  287  Cases_Guinea  2769.0
# 3       1/2/2015  286  Cases_Guinea     NaN
# 4     12/31/2014  284  Cases_Guinea  2730.0
# ...          ...  ...           ...     ...
# 1947   3/27/2014    5   Deaths_Mali     NaN
# 1948   3/26/2014    4   Deaths_Mali     NaN
# 1949   3/25/2014    3   Deaths_Mali     NaN
# 1950   3/24/2014    2   Deaths_Mali     NaN
# 1951   3/22/2014    0   Deaths_Mali     NaN
#
# [1952 rows x 4 columns]

# %%
df.groupby('Country')['count'].mean().plot(kind ='bar', figsize =(11,5))

# %% [markdown]
# # string manipulation
